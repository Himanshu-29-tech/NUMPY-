# %%
import numpy as np
import time

# %%
arr = np.array([1,2,3,4,5])
print(arr, type(arr))
# Out:
# [1 2 3 4 5] <class 'numpy.ndarray'>

# %%
#execution performance
size = 1_000_000

#python list
py_list = list(range(size)) #[1,2,3,4..........]
start = time.time() #give current time value
sq_list = [x**2 for x in py_list]
end = time.time()
print(f"python list time = {end-start} seeconds")


#numpay arrays
np_arr = np.array(py_list)
start = time.time()
sq_array = np_arr ** 2
end = time.time()
print(f"pytnon list time = {end-start} seconds")
# Out:
# python list time = 0.09366011619567871 seeconds
# pytnon list time = 0.004149198532104492 seconds

# %%
# in memory terms
import sys

print(f"python list size = {sys.getsizeof(py_list) * len(py_list)} bytes")

print(f"numpay array size = {np_arr.nbytes} bytes")
# Out:
# python list size = 8000056000000 bytes
# numpay array size = 8000000 bytes
